# %% [markdown]
# <a href="https://colab.research.google.com/github/alimohamad2448-pixel/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
# **Date:** 01/20/2026
# This notebook demonstrates basic Python concepts including:
# - Print statements
# - Variables
# - Basic arithmetic operations
# - String formatting

# %%
print("Welcome to Google Collab!")
print("Python makes programming fun!")
# Out:
# Welcome to Google Collab!
# Python makes programming fun!

# %%
favorite_food = "pasta"
favorite_number = 24
favorite_color = "blue"

# %%
print("My favorite food is:", favorite_food)
print("My favorite number is:", favorite_number)
print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: pasta
# My favorite number is: 24
# My favorite color is: blue

# %%
favorite_video_game = "Madden NFL 2008"
favorite_video_game_console = "Playstation 2"

# %%
print(f"My favorite video game is {favorite_video_game} for the {favorite_video_game_console}")
# Out:
# My favorite video game is Madden NFL 2008 for the Playstation 2
